# %%
#!pip install tensorflow

# %%
import psycopg2
import pandas as pd
from keras.utils import np_utils
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import RobustScaler,StandardScaler,MinMaxScaler
from keras.models import Sequential,load_model
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.utils import resample
from imblearn.over_sampling import ADASYN
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support, recall_score
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from imblearn.over_sampling import SMOTE
from sklearn.svm import SVC
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
from keras.layers import Dense, Dropout,Flatten,LeakyReLU,Conv1D,MaxPooling1D, Activation,SpatialDropout1D,GlobalAveragePooling1D,BatchNormalization
from keras.models import model_from_json
import tensorflow as tf
from keras.callbacks import EarlyStopping
# Out:
# 2023-11-20 16:30:06.718127: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-20 16:30:08.122892: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-11-20 16:30:08.123013: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-11-20 16:30:08.123022: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
conn=psycopg2.connect(database='mimiciv',user='hyu',password='qlrqod123',host='127.0.0.1',port='5432')
print('Open successfully')
cursor=conn.cursor()
# Out:
# Open successfully

# %%
patient=pd.read_sql_query('select distinct on (patient.subject_id) patient.subject_id,gender,anchor_age, ethnicity,icd_code from mimiciv.admission inner join mimiciv.patient on admission.subject_id=patient.subject_id inner join mimiciv.diagnoses_icd on diagnoses_icd.subject_id=patient.subject_id order by patient.subject_id',conn)
patient.drop(patient[(patient.anchor_age==0)].index,axis=0,inplace=True)
patient.reset_index(drop=True,inplace=True)
print(patient.shape)
# Out:
# (194275, 5)

# %%
icd_code=pd.read_sql_query("select distinct on(subject_id) subject_id,icd_code from mimiciv.diagnoses_icd where icd_code like '%E782%' or icd_code like '%E784%' or icd_code like '%E785%' or icd_code like '2722%' or icd_code like '2724%' order by subject_id",conn)
print(len(icd_code))
# Out:
# 58176

# %%
ids=list(icd_code['subject_id'])
for i in ids:
    patient.loc[(patient.subject_id==i),'icd_code']='1'

# %%
patient.icd_code.value_counts()
# Out:
# 1          58174
# 4019        3229
# 30500       2070
# 78650       1752
# 311         1487
#            ...
# S82021A        1
# 6018           1
# D354           1
# N8353          1
# O3123X0        1
# Name: icd_code, Length: 10184, dtype: int64

# %%
chartevent=pd.read_sql_query('select subject_id,charttime,itemid,value,valueuom from mimiciv.chartevents where itemid=226730 or itemid=226512 or itemid=220621 order by subject_id,itemid,charttime',conn) #or itemid=220179 or itemid=220180
chartevent['value']=pd.to_numeric(chartevent['value'],errors='coerce')
chartevent.drop_duplicates(['subject_id','itemid'],keep='first',inplace=True)
chartevent.reset_index(drop=True,inplace=True)
chartfeatures=chartevent.pivot(index='subject_id',columns='itemid',values='value')
chartfeatures.reset_index(inplace=True)
chartfeatures_fillna=chartfeatures.fillna(chartfeatures.mean())
print(chartfeatures_fillna.shape)
# Out:
# (53129, 4)

# %%
chartfeatures_fillna.columns=['subject_id','glucose','weight','height']  
df_new=patient.merge(chartfeatures_fillna)
df_new.rename(columns={'anchor_age':'age'},inplace=True)
df_new.loc[df_new['icd_code']!='1','icd_code']=0
df_new.icd_code.value_counts()
# Out:
# 0    28783
# 1    24330
# Name: icd_code, dtype: int64

# %%
df_new.drop('subject_id',axis=1,inplace=True)
df_new.drop(df_new[df_new.glucose>1000].index,axis=0,inplace=True)
df_new.drop(df_new[df_new.weight>200].index,axis=0,inplace=True)
df_new.drop(df_new[df_new.height>200].index,axis=0,inplace=True)

df_new.reset_index(drop=True,inplace=True)
df_new.shape
# Out:
# (52925, 7)

# %%
df_new.drop(df_new[df_new.height==0].index,axis=0,inplace=True)
df_new.reset_index(drop=True,inplace=True)
df_new['BMI']=round(df_new['weight']/((df_new['height']/100)**2),2)
df_new.drop(df_new[df_new['BMI']>100].index,axis=0,inplace=True)
df_new.reset_index(drop=True,inplace=True)

df_new=df_new[['age','gender','glucose','weight','height','BMI','icd_code']]  #'ethnicity','DBP','SBP','creatine',
df_new
# Out:
#        age gender     glucose  weight      height    BMI icd_code
# 0       52      F  115.000000    39.4  152.000000  17.05        0
# 1       73      F  450.197846    76.2  168.824223  26.74        1
# 2       55      F  113.000000    71.2  168.824223  24.98        0
# 3       46      F  146.000000    72.2  157.000000  29.29        0
# 4       68      F  148.000000    65.0  157.000000  26.37        1
# ...    ...    ...         ...     ...         ...    ...      ...
# 52739   41      M  136.000000   107.5  193.000000  28.86        0
# 52740   81      M  175.000000    50.5  168.824223  17.72        0
# 52741   46      F  195.000000    67.9  168.824223  23.82        0
# 52742   58      M   98.000000    77.5  178.000000  24.46        1
# 52743   57      F  113.000000    94.0  168.824223  32.98        0
#
# [52744 rows x 7 columns]

# %%
df_final=df_new.copy()
gender_map={'M':0,'F':1}
df_final['gender']=df_final['gender'].map(gender_map)
df_final.icd_code=pd.to_numeric(df_final.icd_code,errors='coerce')

# %%
fig=plt.subplots(figsize=(10,10))
ht=df_final.corr()
sns.heatmap(ht,annot=True)
plt.show()

# %%
df_final[['glucose','icd_code']]
df_final.icd_code.value_counts()
# Out:
# 0    28542
# 1    24202
# Name: icd_code, dtype: int64

# %%
df_abnormal=df_final.loc[(df_final.glucose>=100),:]
df_abnormal.icd_code.value_counts()
# Out:
# 0    22173
# 1    20093
# Name: icd_code, dtype: int64

# %%
df_abnormal_only=df_abnormal.loc[df_abnormal.icd_code==1,:]
df_abnormal_only.reset_index(drop=True,inplace=True)
df_abnormal_only
# Out:
#        age  gender     glucose  weight      height    BMI  icd_code
# 0       73       1  450.197846    76.2  168.824223  26.74         1
# 1       68       1  148.000000    65.0  157.000000  26.37         1
# 2       86       0  200.000000    58.0  168.824223  20.35         1
# 3       53       0  226.000000   156.1  178.000000  49.27         1
# 4       81       0  264.000000    64.1  170.000000  22.18         1
# ...    ...     ...         ...     ...         ...    ...       ...
# 20088   76       0  172.000000   134.5  180.000000  41.51         1
# 20089   52       1  138.000000    85.0  160.000000  33.20         1
# 20090   66       1  100.000000    86.0  170.000000  29.76         1
# 20091   71       1  275.000000    76.3  168.824223  26.77         1
# 20092   71       1  115.000000    93.9  163.000000  35.34         1
#
# [20093 rows x 7 columns]

# %%
df_normal=df_final.loc[(df_final.glucose<100),:]
df_normal.icd_code.value_counts()
# Out:
# 0    6369
# 1    4109
# Name: icd_code, dtype: int64

# %%
df_normal_only=df_normal.loc[df_normal.icd_code==0,:]
df_normal_only.reset_index(drop=True,inplace=True)
df_normal_only
# Out:
#       age  gender  glucose  weight      height    BMI  icd_code
# 0      21       0     88.0    82.0  178.000000  25.88         0
# 1      24       0     90.0    67.0  168.824223  23.51         0
# 2      56       0     99.0    91.0  185.000000  26.59         0
# 3      51       0     86.0   112.5  180.000000  34.72         0
# 4      61       1     89.0    45.2  152.000000  19.56         0
# ...   ...     ...      ...     ...         ...    ...       ...
# 6364   56       0     78.0    62.0  168.824223  21.75         0
# 6365   26       0     96.0   106.5  168.824223  37.37         0
# 6366   29       0     78.0    69.5  175.000000  22.69         0
# 6367   47       0     87.0    70.0  157.000000  28.40         0
# 6368   52       1     93.0    49.4  157.000000  20.04         0
#
# [6369 rows x 7 columns]

# %%
from sklearn.utils import shuffle
df=pd.concat([df_abnormal_only,df_normal_only])
df_shuffled=shuffle(df)
df_shuffled=df_shuffled.reset_index(drop=True)
df_shuffled
# Out:
#        age  gender  glucose  weight      height    BMI  icd_code
# 0       66       1    251.0    55.0  163.000000  20.70         1
# 1       75       0    240.0    79.9  170.000000  27.65         1
# 2       68       0    140.0    94.0  179.000000  29.34         1
# 3       57       0    159.0   110.0  168.824223  38.59         1
# 4       81       1    146.0    54.4  168.824223  19.09         1
# ...    ...     ...      ...     ...         ...    ...       ...
# 26457   75       1     84.0    65.0  163.000000  24.46         0
# 26458   75       0    110.0    71.0  168.824223  24.91         1
# 26459   30       0     87.0    88.2  168.824223  30.95         0
# 26460   91       1     48.0    61.9  168.824223  21.72         0
# 26461   55       0    107.0   118.0  183.000000  35.24         1
#
# [26462 rows x 7 columns]

# %%
fig=plt.subplots(figsize=(10,10))
ht=df_shuffled.corr()
sns.heatmap(ht,annot=True)
plt.show()

# %%
df_shuffled.to_csv('df_final_version.csv',index=False)
df_shuffled=pd.read_csv('df_final_version.csv')

# %%
# Y=df_shuffled[['icd_code']].values
# X=df_shuffled[['age','gender','glucose','BMI','weight', 'height']].values  #'ethnicity','DBP','SBP','creatine',

# scaler=MinMaxScaler()
# scaler.fit(X)
# X_scaled=scaler.transform(X)
# Y_onehot=np_utils.to_categorical(Y)
# X_train,X_test,y_train,y_test=train_test_split(X_scaled,Y_onehot,test_size=0.2,random_state=0)

# %%
# def dnn_model():
#     model=Sequential()
#     model.add(Dense(32,input_shape=(6,),activation='relu'))
#     model.add(Dense(32,activation='relu'))
#     model.add(BatchNormalization())
#     model.add(Dense(64,activation='relu'))
#     model.add(Dense(64,activation='relu'))
#     model.add(BatchNormalization())
#     model.add(Dropout(0.4))
#     model.add(Dense(16,activation='relu'))
#     model.add(Dense(16,activation='relu'))
#     model.add(BatchNormalization())
#     model.add(Dropout(0.4))
#     model.add(Dense(8,activation='relu'))
#     model.add(Dense(8,activation='relu'))
#     model.add(BatchNormalization())
#     model.add(Flatten())
#     model.add(Dropout(0.4))
#     model.add(Dense(2,activation='softmax'))
#     return model
# dnn=dnn_model()
# early_stopping = EarlyStopping(monitor='val_loss', patience=50, verbose=2)
# dnn.compile(loss='categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])
# history=dnn.fit(X_train,y_train,batch_size=64,epochs=200,shuffle=False,verbose=1,validation_data=(X_test,y_test),callbacks=[early_stopping])

# %%
# score=dnn.evaluate(X_test,y_test)
# print('Test loss:',score[0])
# print('Test accuracy:',score[1])
# plt.plot(history.epoch,history.history.get('val_accuracy'),c='g',label='validation acc')
# plt.plot(history.epoch,history.history.get('accuracy'),c='b',label='train acc')
# plt.legend()

# %%
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score,f1_score,precision_score
# pred=np.argmax(dnn.predict(X_test),axis=1)
# y_t=np.argmax(y_test,axis=1)
# print('precision score:',precision_score(y_t,pred))
# print('f1 score:',f1_score(y_t,pred))
# print('recall score:',recall_score(y_t,pred))
# print('accuracy score:',accuracy_score(y_t,pred))

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import joblib

Y=df_shuffled[['icd_code']].values
X=df_shuffled[['glucose','age','gender','BMI','weight','height']].values

scaler=MinMaxScaler()
scaler.fit(X)
X_scaled=scaler.transform(X)
X_scaled=np.expand_dims(X_scaled,axis=2) 
joblib.dump(scaler, '/Data4TB/zhan/mimiciv_hyperlipidemia/scaler.pkl') 
 
Y_onehot=np_utils.to_categorical(Y)
X_train,X_test,y_train,y_test=train_test_split(X_scaled,Y_onehot,test_size=0.15,random_state=0)
def cnn_model():
    model=Sequential()
    model.add(Conv1D(32,3,input_shape=(6,1),activation='tanh',padding='same'))
    model.add(MaxPooling1D(3,padding='same'))
    model.add(SpatialDropout1D(0.3))
    model.add(Conv1D(64,3,activation='tanh',padding='same'))
    model.add(MaxPooling1D(3,padding='same'))
    model.add(SpatialDropout1D(0.3))
    model.add(Flatten())
    model.add(Dense(2,activation='softmax'))
    # print(model.summary())
    model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
    return model
cnn=cnn_model()
early_stopping = EarlyStopping(monitor='val_loss', patience=50, verbose=2)
# estimator=KerasClassifier(build_fn=cnn_model,epochs=200,batch_size=16,verbose=1,validation_data=(X_test,y_test))
history=cnn.fit(X_train,y_train,epochs=200,batch_size=32,shuffle=False,verbose=1,validation_data=(X_test,y_test),callbacks=[early_stopping])
score=cnn.evaluate(X_test,y_test)
print('Test loss:',score[0])
print('Test accuracy:',score[1])
plt.plot(history.epoch,history.history.get('val_accuracy'),c='g',label='validation acc')
plt.plot(history.epoch,history.history.get('accuracy'),c='b',label='train acc')
plt.legend()
# Out:
# 2023-11-20 17:08:35.513259: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-20 17:08:35.525627: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-11-20 17:08:35.525681: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-11-20 17:08:35.530369: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/200
# 703/703 [==============================] - 7s 8ms/step - loss: 0.3562 - accuracy: 0.8468 - val_loss: 0.1776 - val_accuracy: 0.9043
# Epoch 2/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.1301 - accuracy: 0.9563 - val_loss: 0.0836 - val_accuracy: 0.9657
# Epoch 3/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0831 - accuracy: 0.9735 - val_loss: 0.0556 - val_accuracy: 0.9806
# Epoch 4/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0658 - accuracy: 0.9781 - val_loss: 0.0455 - val_accuracy: 0.9829
# Epoch 5/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0564 - accuracy: 0.9812 - val_loss: 0.0295 - val_accuracy: 0.9960
# Epoch 6/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0517 - accuracy: 0.9826 - val_loss: 0.0261 - val_accuracy: 0.9955
# Epoch 7/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0518 - accuracy: 0.9820 - val_loss: 0.0220 - val_accuracy: 0.9967
# Epoch 8/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0451 - accuracy: 0.9844 - val_loss: 0.0205 - val_accuracy: 0.9950
# Epoch 9/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0417 - accuracy: 0.9855 - val_loss: 0.0202 - val_accuracy: 0.9945
# Epoch 10/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0428 - accuracy: 0.9846 - val_loss: 0.0166 - val_accuracy: 0.9972
# Epoch 11/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0373 - accuracy: 0.9876 - val_loss: 0.0182 - val_accuracy: 0.9935
# Epoch 12/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0392 - accuracy: 0.9854 - val_loss: 0.0140 - val_accuracy: 0.9970
# Epoch 13/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0381 - accuracy: 0.9870 - val_loss: 0.0138 - val_accuracy: 0.9975
# Epoch 14/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0384 - accuracy: 0.9864 - val_loss: 0.0130 - val_accuracy: 0.9980
# Epoch 15/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0339 - accuracy: 0.9874 - val_loss: 0.0125 - val_accuracy: 0.9977
# Epoch 16/200
# 703/703 [==============================] - 5s 7ms/step - loss: 0.0359 - accuracy: 0.9873 - val_loss: 0.0131 - val_accuracy: 0.9972
# Epoch 17/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0334 - accuracy: 0.9875 - val_loss: 0.0126 - val_accuracy: 0.9975
# Epoch 18/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0316 - accuracy: 0.9890 - val_loss: 0.0182 - val_accuracy: 0.9902
# Epoch 19/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0363 - accuracy: 0.9867 - val_loss: 0.0132 - val_accuracy: 0.9965
# Epoch 20/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0360 - accuracy: 0.9870 - val_loss: 0.0113 - val_accuracy: 0.9982
# Epoch 21/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0283 - accuracy: 0.9901 - val_loss: 0.0118 - val_accuracy: 0.9977
# Epoch 22/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0313 - accuracy: 0.9886 - val_loss: 0.0108 - val_accuracy: 0.9977
# Epoch 23/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0330 - accuracy: 0.9879 - val_loss: 0.0119 - val_accuracy: 0.9965
# Epoch 24/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0296 - accuracy: 0.9888 - val_loss: 0.0110 - val_accuracy: 0.9972
# Epoch 25/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0294 - accuracy: 0.9892 - val_loss: 0.0106 - val_accuracy: 0.9972
# Epoch 26/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0334 - accuracy: 0.9877 - val_loss: 0.0115 - val_accuracy: 0.9967
# Epoch 27/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0332 - accuracy: 0.9874 - val_loss: 0.0109 - val_accuracy: 0.9975
# Epoch 28/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0303 - accuracy: 0.9889 - val_loss: 0.0123 - val_accuracy: 0.9955
# Epoch 29/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0279 - accuracy: 0.9893 - val_loss: 0.0100 - val_accuracy: 0.9982
# Epoch 30/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0277 - accuracy: 0.9892 - val_loss: 0.0098 - val_accuracy: 0.9982
# Epoch 31/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0295 - accuracy: 0.9895 - val_loss: 0.0096 - val_accuracy: 0.9982
# Epoch 32/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0311 - accuracy: 0.9884 - val_loss: 0.0112 - val_accuracy: 0.9972
# Epoch 33/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0282 - accuracy: 0.9896 - val_loss: 0.0171 - val_accuracy: 0.9902
# Epoch 34/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0279 - accuracy: 0.9888 - val_loss: 0.0115 - val_accuracy: 0.9955
# Epoch 35/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0274 - accuracy: 0.9895 - val_loss: 0.0103 - val_accuracy: 0.9977
# Epoch 36/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0290 - accuracy: 0.9890 - val_loss: 0.0094 - val_accuracy: 0.9982
# Epoch 37/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0282 - accuracy: 0.9891 - val_loss: 0.0100 - val_accuracy: 0.9982
# Epoch 38/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0290 - accuracy: 0.9890 - val_loss: 0.0099 - val_accuracy: 0.9975
# Epoch 39/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0290 - accuracy: 0.9891 - val_loss: 0.0098 - val_accuracy: 0.9975
# Epoch 40/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0286 - accuracy: 0.9894 - val_loss: 0.0094 - val_accuracy: 0.9982
# Epoch 41/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0278 - accuracy: 0.9896 - val_loss: 0.0156 - val_accuracy: 0.9929
# Epoch 42/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0272 - accuracy: 0.9899 - val_loss: 0.0166 - val_accuracy: 0.9922
# Epoch 43/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0301 - accuracy: 0.9894 - val_loss: 0.0101 - val_accuracy: 0.9975
# Epoch 44/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0251 - accuracy: 0.9905 - val_loss: 0.0095 - val_accuracy: 0.9977
# Epoch 45/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0242 - accuracy: 0.9907 - val_loss: 0.0110 - val_accuracy: 0.9957
# Epoch 46/200
# 703/703 [==============================] - 5s 7ms/step - loss: 0.0332 - accuracy: 0.9881 - val_loss: 0.0093 - val_accuracy: 0.9985
# Epoch 47/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0267 - accuracy: 0.9901 - val_loss: 0.0092 - val_accuracy: 0.9982
# Epoch 48/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0254 - accuracy: 0.9907 - val_loss: 0.0099 - val_accuracy: 0.9970
# Epoch 49/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0259 - accuracy: 0.9900 - val_loss: 0.0103 - val_accuracy: 0.9962
# Epoch 50/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0273 - accuracy: 0.9900 - val_loss: 0.0090 - val_accuracy: 0.9985
# Epoch 51/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0305 - accuracy: 0.9888 - val_loss: 0.0094 - val_accuracy: 0.9985
# Epoch 52/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0259 - accuracy: 0.9896 - val_loss: 0.0093 - val_accuracy: 0.9980
# Epoch 53/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0272 - accuracy: 0.9898 - val_loss: 0.0132 - val_accuracy: 0.9940
# Epoch 54/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0272 - accuracy: 0.9903 - val_loss: 0.0102 - val_accuracy: 0.9967
# Epoch 55/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0248 - accuracy: 0.9909 - val_loss: 0.0089 - val_accuracy: 0.9982
# Epoch 56/200
# 703/703 [==============================] - 5s 7ms/step - loss: 0.0259 - accuracy: 0.9904 - val_loss: 0.0096 - val_accuracy: 0.9977
# Epoch 57/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0317 - accuracy: 0.9884 - val_loss: 0.0138 - val_accuracy: 0.9945
# Epoch 58/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0248 - accuracy: 0.9910 - val_loss: 0.0088 - val_accuracy: 0.9982
# Epoch 59/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0261 - accuracy: 0.9901 - val_loss: 0.0092 - val_accuracy: 0.9972
# Epoch 60/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0262 - accuracy: 0.9903 - val_loss: 0.0103 - val_accuracy: 0.9967
# Epoch 61/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0236 - accuracy: 0.9916 - val_loss: 0.0086 - val_accuracy: 0.9975
# Epoch 62/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0254 - accuracy: 0.9902 - val_loss: 0.0082 - val_accuracy: 0.9995
# Epoch 63/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0288 - accuracy: 0.9895 - val_loss: 0.0087 - val_accuracy: 0.9990
# Epoch 64/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0256 - accuracy: 0.9907 - val_loss: 0.0090 - val_accuracy: 0.9970
# Epoch 65/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0258 - accuracy: 0.9902 - val_loss: 0.0103 - val_accuracy: 0.9972
# Epoch 66/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0252 - accuracy: 0.9898 - val_loss: 0.0091 - val_accuracy: 0.9972
# Epoch 67/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0274 - accuracy: 0.9896 - val_loss: 0.0087 - val_accuracy: 0.9987
# Epoch 68/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0269 - accuracy: 0.9893 - val_loss: 0.0086 - val_accuracy: 0.9990
# Epoch 69/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0221 - accuracy: 0.9915 - val_loss: 0.0197 - val_accuracy: 0.9889
# Epoch 70/200
# 703/703 [==============================] - 5s 7ms/step - loss: 0.0281 - accuracy: 0.9898 - val_loss: 0.0095 - val_accuracy: 0.9977
# Epoch 71/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0268 - accuracy: 0.9900 - val_loss: 0.0108 - val_accuracy: 0.9967
# Epoch 72/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0255 - accuracy: 0.9900 - val_loss: 0.0090 - val_accuracy: 0.9982
# Epoch 73/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0261 - accuracy: 0.9903 - val_loss: 0.0090 - val_accuracy: 0.9980
# Epoch 74/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0222 - accuracy: 0.9916 - val_loss: 0.0092 - val_accuracy: 0.9967
# Epoch 75/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0263 - accuracy: 0.9899 - val_loss: 0.0296 - val_accuracy: 0.9856
# Epoch 76/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0252 - accuracy: 0.9909 - val_loss: 0.0103 - val_accuracy: 0.9955
# Epoch 77/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0249 - accuracy: 0.9903 - val_loss: 0.0089 - val_accuracy: 0.9977
# Epoch 78/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0269 - accuracy: 0.9903 - val_loss: 0.0118 - val_accuracy: 0.9955
# Epoch 79/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0263 - accuracy: 0.9905 - val_loss: 0.0106 - val_accuracy: 0.9967
# Epoch 80/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0230 - accuracy: 0.9905 - val_loss: 0.0081 - val_accuracy: 0.9990
# Epoch 81/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0234 - accuracy: 0.9908 - val_loss: 0.0082 - val_accuracy: 0.9985
# Epoch 82/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0232 - accuracy: 0.9912 - val_loss: 0.0082 - val_accuracy: 0.9975
# Epoch 83/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0262 - accuracy: 0.9897 - val_loss: 0.0087 - val_accuracy: 0.9977
# Epoch 84/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0224 - accuracy: 0.9911 - val_loss: 0.0080 - val_accuracy: 0.9982
# Epoch 85/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0238 - accuracy: 0.9911 - val_loss: 0.0076 - val_accuracy: 0.9992
# Epoch 86/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0243 - accuracy: 0.9901 - val_loss: 0.0081 - val_accuracy: 0.9985
# Epoch 87/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0261 - accuracy: 0.9905 - val_loss: 0.0085 - val_accuracy: 0.9985
# Epoch 88/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0249 - accuracy: 0.9907 - val_loss: 0.0147 - val_accuracy: 0.9937
# Epoch 89/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0218 - accuracy: 0.9920 - val_loss: 0.0086 - val_accuracy: 0.9967
# Epoch 90/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0247 - accuracy: 0.9905 - val_loss: 0.0104 - val_accuracy: 0.9962
# Epoch 91/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0212 - accuracy: 0.9919 - val_loss: 0.0083 - val_accuracy: 0.9967
# Epoch 92/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0259 - accuracy: 0.9901 - val_loss: 0.0135 - val_accuracy: 0.9945
# Epoch 93/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0230 - accuracy: 0.9912 - val_loss: 0.0104 - val_accuracy: 0.9960
# Epoch 94/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0242 - accuracy: 0.9910 - val_loss: 0.0082 - val_accuracy: 0.9977
# Epoch 95/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0215 - accuracy: 0.9919 - val_loss: 0.0077 - val_accuracy: 0.9985
# Epoch 96/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0244 - accuracy: 0.9909 - val_loss: 0.0085 - val_accuracy: 0.9972
# Epoch 97/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0227 - accuracy: 0.9915 - val_loss: 0.0093 - val_accuracy: 0.9970
# Epoch 98/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0265 - accuracy: 0.9907 - val_loss: 0.0154 - val_accuracy: 0.9935
# Epoch 99/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0227 - accuracy: 0.9917 - val_loss: 0.0091 - val_accuracy: 0.9972
# Epoch 100/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0241 - accuracy: 0.9904 - val_loss: 0.0081 - val_accuracy: 0.9980
# Epoch 101/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0239 - accuracy: 0.9914 - val_loss: 0.0083 - val_accuracy: 0.9975
# Epoch 102/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0228 - accuracy: 0.9912 - val_loss: 0.0208 - val_accuracy: 0.9887
# Epoch 103/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0229 - accuracy: 0.9916 - val_loss: 0.0081 - val_accuracy: 0.9977
# Epoch 104/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0229 - accuracy: 0.9916 - val_loss: 0.0110 - val_accuracy: 0.9950
# Epoch 105/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0241 - accuracy: 0.9914 - val_loss: 0.0077 - val_accuracy: 0.9990
# Epoch 106/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0202 - accuracy: 0.9929 - val_loss: 0.0072 - val_accuracy: 0.9992
# Epoch 107/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0235 - accuracy: 0.9910 - val_loss: 0.0077 - val_accuracy: 0.9992
# Epoch 108/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0217 - accuracy: 0.9920 - val_loss: 0.0103 - val_accuracy: 0.9965
# Epoch 109/200
# 703/703 [==============================] - 5s 7ms/step - loss: 0.0217 - accuracy: 0.9913 - val_loss: 0.0098 - val_accuracy: 0.9957
# Epoch 110/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0206 - accuracy: 0.9928 - val_loss: 0.0072 - val_accuracy: 0.9985
# Epoch 111/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0218 - accuracy: 0.9915 - val_loss: 0.0071 - val_accuracy: 0.9987
# Epoch 112/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0247 - accuracy: 0.9906 - val_loss: 0.0100 - val_accuracy: 0.9965
# Epoch 113/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0247 - accuracy: 0.9905 - val_loss: 0.0130 - val_accuracy: 0.9947
# Epoch 114/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0227 - accuracy: 0.9921 - val_loss: 0.0075 - val_accuracy: 0.9987
# Epoch 115/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0223 - accuracy: 0.9920 - val_loss: 0.0078 - val_accuracy: 0.9972
# Epoch 116/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0247 - accuracy: 0.9912 - val_loss: 0.0075 - val_accuracy: 0.9992
# Epoch 117/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0192 - accuracy: 0.9923 - val_loss: 0.0070 - val_accuracy: 0.9987
# Epoch 118/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0240 - accuracy: 0.9906 - val_loss: 0.0074 - val_accuracy: 0.9985
# Epoch 119/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0210 - accuracy: 0.9922 - val_loss: 0.0071 - val_accuracy: 0.9987
# Epoch 120/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0222 - accuracy: 0.9917 - val_loss: 0.0089 - val_accuracy: 0.9972
# Epoch 121/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0223 - accuracy: 0.9920 - val_loss: 0.0074 - val_accuracy: 0.9975
# Epoch 122/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0224 - accuracy: 0.9912 - val_loss: 0.0086 - val_accuracy: 0.9972
# Epoch 123/200
# 703/703 [==============================] - 5s 7ms/step - loss: 0.0220 - accuracy: 0.9918 - val_loss: 0.0084 - val_accuracy: 0.9972
# Epoch 124/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0209 - accuracy: 0.9926 - val_loss: 0.0078 - val_accuracy: 0.9972
# Epoch 125/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0232 - accuracy: 0.9912 - val_loss: 0.0117 - val_accuracy: 0.9950
# Epoch 126/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0214 - accuracy: 0.9918 - val_loss: 0.0072 - val_accuracy: 0.9992
# Epoch 127/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0201 - accuracy: 0.9920 - val_loss: 0.0073 - val_accuracy: 0.9992
# Epoch 128/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0203 - accuracy: 0.9925 - val_loss: 0.0067 - val_accuracy: 0.9992
# Epoch 129/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0223 - accuracy: 0.9914 - val_loss: 0.0071 - val_accuracy: 0.9977
# Epoch 130/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0201 - accuracy: 0.9928 - val_loss: 0.0072 - val_accuracy: 0.9977
# Epoch 131/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0229 - accuracy: 0.9912 - val_loss: 0.0091 - val_accuracy: 0.9967
# Epoch 132/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0206 - accuracy: 0.9925 - val_loss: 0.0073 - val_accuracy: 0.9992
# Epoch 133/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0206 - accuracy: 0.9920 - val_loss: 0.0112 - val_accuracy: 0.9950
# Epoch 134/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0222 - accuracy: 0.9919 - val_loss: 0.0069 - val_accuracy: 0.9992
# Epoch 135/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0213 - accuracy: 0.9912 - val_loss: 0.0068 - val_accuracy: 0.9992
# Epoch 136/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0244 - accuracy: 0.9913 - val_loss: 0.0097 - val_accuracy: 0.9955
# Epoch 137/200
# 703/703 [==============================] - 5s 7ms/step - loss: 0.0207 - accuracy: 0.9920 - val_loss: 0.0120 - val_accuracy: 0.9950
# Epoch 138/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0200 - accuracy: 0.9932 - val_loss: 0.0077 - val_accuracy: 0.9975
# Epoch 139/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0241 - accuracy: 0.9915 - val_loss: 0.0105 - val_accuracy: 0.9957
# Epoch 140/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0203 - accuracy: 0.9924 - val_loss: 0.0134 - val_accuracy: 0.9937
# Epoch 141/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0217 - accuracy: 0.9916 - val_loss: 0.0110 - val_accuracy: 0.9952
# Epoch 142/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0225 - accuracy: 0.9913 - val_loss: 0.0101 - val_accuracy: 0.9962
# Epoch 143/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0196 - accuracy: 0.9930 - val_loss: 0.0068 - val_accuracy: 0.9990
# Epoch 144/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0251 - accuracy: 0.9907 - val_loss: 0.0094 - val_accuracy: 0.9960
# Epoch 145/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0201 - accuracy: 0.9925 - val_loss: 0.0081 - val_accuracy: 0.9972
# Epoch 146/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0210 - accuracy: 0.9923 - val_loss: 0.0081 - val_accuracy: 0.9977
# Epoch 147/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0219 - accuracy: 0.9915 - val_loss: 0.0073 - val_accuracy: 0.9990
# Epoch 148/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0197 - accuracy: 0.9929 - val_loss: 0.0099 - val_accuracy: 0.9960
# Epoch 149/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0226 - accuracy: 0.9919 - val_loss: 0.0074 - val_accuracy: 0.9987
# Epoch 150/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0214 - accuracy: 0.9927 - val_loss: 0.0137 - val_accuracy: 0.9935
# Epoch 151/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0225 - accuracy: 0.9915 - val_loss: 0.0137 - val_accuracy: 0.9937
# Epoch 152/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0198 - accuracy: 0.9928 - val_loss: 0.0081 - val_accuracy: 0.9972
# Epoch 153/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0196 - accuracy: 0.9920 - val_loss: 0.0069 - val_accuracy: 0.9992
# Epoch 154/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0244 - accuracy: 0.9914 - val_loss: 0.0102 - val_accuracy: 0.9955
# Epoch 155/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0204 - accuracy: 0.9925 - val_loss: 0.0080 - val_accuracy: 0.9972
# Epoch 156/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0212 - accuracy: 0.9920 - val_loss: 0.0097 - val_accuracy: 0.9972
# Epoch 157/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0219 - accuracy: 0.9917 - val_loss: 0.0099 - val_accuracy: 0.9960
# Epoch 158/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0193 - accuracy: 0.9929 - val_loss: 0.0071 - val_accuracy: 0.9982
# Epoch 159/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0186 - accuracy: 0.9933 - val_loss: 0.0065 - val_accuracy: 0.9992
# Epoch 160/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0225 - accuracy: 0.9918 - val_loss: 0.0102 - val_accuracy: 0.9952
# Epoch 161/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0216 - accuracy: 0.9922 - val_loss: 0.0072 - val_accuracy: 0.9980
# Epoch 162/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0189 - accuracy: 0.9930 - val_loss: 0.0070 - val_accuracy: 0.9980
# Epoch 163/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0191 - accuracy: 0.9927 - val_loss: 0.0070 - val_accuracy: 0.9975
# Epoch 164/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0222 - accuracy: 0.9917 - val_loss: 0.0071 - val_accuracy: 0.9975
# Epoch 165/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0203 - accuracy: 0.9922 - val_loss: 0.0086 - val_accuracy: 0.9967
# Epoch 166/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0213 - accuracy: 0.9921 - val_loss: 0.0100 - val_accuracy: 0.9952
# Epoch 167/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0208 - accuracy: 0.9924 - val_loss: 0.0080 - val_accuracy: 0.9967
# Epoch 168/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0203 - accuracy: 0.9924 - val_loss: 0.0073 - val_accuracy: 0.9972
# Epoch 169/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0210 - accuracy: 0.9924 - val_loss: 0.0083 - val_accuracy: 0.9972
# Epoch 170/200
# 703/703 [==============================] - 5s 7ms/step - loss: 0.0196 - accuracy: 0.9929 - val_loss: 0.0117 - val_accuracy: 0.9955
# Epoch 171/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0194 - accuracy: 0.9926 - val_loss: 0.0091 - val_accuracy: 0.9955
# Epoch 172/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0187 - accuracy: 0.9928 - val_loss: 0.0112 - val_accuracy: 0.9950
# Epoch 173/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0186 - accuracy: 0.9931 - val_loss: 0.0068 - val_accuracy: 0.9987
# Epoch 174/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0214 - accuracy: 0.9920 - val_loss: 0.0082 - val_accuracy: 0.9962
# Epoch 175/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0210 - accuracy: 0.9926 - val_loss: 0.0123 - val_accuracy: 0.9942
# Epoch 176/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0192 - accuracy: 0.9931 - val_loss: 0.0065 - val_accuracy: 0.9992
# Epoch 177/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0202 - accuracy: 0.9928 - val_loss: 0.0068 - val_accuracy: 0.9990
# Epoch 178/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0203 - accuracy: 0.9925 - val_loss: 0.0073 - val_accuracy: 0.9980
# Epoch 179/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0197 - accuracy: 0.9927 - val_loss: 0.0091 - val_accuracy: 0.9957
# Epoch 180/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0213 - accuracy: 0.9924 - val_loss: 0.0138 - val_accuracy: 0.9937
# Epoch 181/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0209 - accuracy: 0.9923 - val_loss: 0.0066 - val_accuracy: 0.9992
# Epoch 182/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0190 - accuracy: 0.9932 - val_loss: 0.0095 - val_accuracy: 0.9955
# Epoch 183/200
# 703/703 [==============================] - 5s 7ms/step - loss: 0.0194 - accuracy: 0.9931 - val_loss: 0.0064 - val_accuracy: 0.9990
# Epoch 184/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0213 - accuracy: 0.9919 - val_loss: 0.0096 - val_accuracy: 0.9960
# Epoch 185/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0200 - accuracy: 0.9928 - val_loss: 0.0071 - val_accuracy: 0.9985
# Epoch 186/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0201 - accuracy: 0.9924 - val_loss: 0.0088 - val_accuracy: 0.9965
# Epoch 187/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0176 - accuracy: 0.9936 - val_loss: 0.0060 - val_accuracy: 0.9997
# Epoch 188/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0215 - accuracy: 0.9917 - val_loss: 0.0064 - val_accuracy: 0.9990
# Epoch 189/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0188 - accuracy: 0.9929 - val_loss: 0.0063 - val_accuracy: 0.9985
# Epoch 190/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0202 - accuracy: 0.9924 - val_loss: 0.0139 - val_accuracy: 0.9937
# Epoch 191/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0203 - accuracy: 0.9925 - val_loss: 0.0064 - val_accuracy: 0.9992
# Epoch 192/200
# 703/703 [==============================] - 5s 8ms/step - loss: 0.0202 - accuracy: 0.9920 - val_loss: 0.0065 - val_accuracy: 0.9985
# Epoch 193/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0199 - accuracy: 0.9923 - val_loss: 0.0097 - val_accuracy: 0.9955
# Epoch 194/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0209 - accuracy: 0.9924 - val_loss: 0.0095 - val_accuracy: 0.9955
# Epoch 195/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0192 - accuracy: 0.9922 - val_loss: 0.0071 - val_accuracy: 0.9977
# Epoch 196/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0191 - accuracy: 0.9927 - val_loss: 0.0081 - val_accuracy: 0.9972
# Epoch 197/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0198 - accuracy: 0.9926 - val_loss: 0.0064 - val_accuracy: 0.9992
# Epoch 198/200
# 703/703 [==============================] - 6s 9ms/step - loss: 0.0214 - accuracy: 0.9919 - val_loss: 0.0079 - val_accuracy: 0.9972
# Epoch 199/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0183 - accuracy: 0.9926 - val_loss: 0.0136 - val_accuracy: 0.9942
# Epoch 200/200
# 703/703 [==============================] - 6s 8ms/step - loss: 0.0184 - accuracy: 0.9930 - val_loss: 0.0125 - val_accuracy: 0.9937
# 125/125 [==============================] - 1s 7ms/step - loss: 0.0125 - accuracy: 0.9937
# Test loss: 0.012453487142920494
# Test accuracy: 0.99370276927948

# %%
pred=np.argmax(cnn.predict(X_test),axis=1)
y_t=np.argmax(y_test,axis=1)
print('precision score:',precision_score(y_t,pred))
print('f1 score:',f1_score(y_t,pred))
print('recall score:',recall_score(y_t,pred))
print('accuracy score:',accuracy_score(y_t,pred))
# Out:
# 125/125 [==============================] - 1s 8ms/step
# precision score: 0.9917518970636754
# f1 score: 0.9958588702998178
# recall score: 1.0
# accuracy score: 0.9937027707808564

# %%
cnn.save("hyperlipidemia.h5")
