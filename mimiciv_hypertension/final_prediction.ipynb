# %%
#!pip install tensorflow

# %%
import psycopg2
import pandas as pd
from keras.utils import np_utils
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import RobustScaler,StandardScaler,MinMaxScaler
from keras.models import Sequential,load_model
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.utils import resample
from imblearn.over_sampling import ADASYN
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support, recall_score
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from imblearn.over_sampling import SMOTE
from sklearn.svm import SVC
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
from keras.layers import Dense, Dropout,Flatten,LeakyReLU,Conv1D,MaxPooling1D, Activation,SpatialDropout1D,GlobalAveragePooling1D,BatchNormalization
from keras.models import model_from_json
import tensorflow as tf
from keras.callbacks import EarlyStopping
# Out:
# 2023-11-22 13:45:00.004859: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-22 13:45:01.260256: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-11-22 13:45:01.260362: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-11-22 13:45:01.260370: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
conn=psycopg2.connect(database='mimiciv',user='hyu',password='qlrqod123',host='127.0.0.1',port='5432')
print('Open successfully')
cursor=conn.cursor()
# Out:
# Open successfully

# %%
patient=pd.read_sql_query('select distinct on (patient.subject_id) patient.subject_id,gender,anchor_age, ethnicity,icd_code from mimiciv.admission inner join mimiciv.patient on admission.subject_id=patient.subject_id inner join mimiciv.diagnoses_icd on diagnoses_icd.subject_id=patient.subject_id order by patient.subject_id',conn)
patient.drop(patient[(patient.anchor_age==0)].index,axis=0,inplace=True)
patient.reset_index(drop=True,inplace=True)
print(patient.shape)
# Out:
# (194275, 5)

# %%
icd_code=pd.read_sql_query("select distinct on(subject_id) subject_id,icd_code from mimiciv.diagnoses_icd where icd_code like '%O10%'or icd_code like '%O11%' or icd_code like '%O12%' or icd_code like '%O13%' or icd_code like '%O14%' or icd_code like '%O15%'or icd_code like '%O16%' or icd_code like '%I15%' or icd_code like '405%' or icd_code like '642%' order by subject_id",conn)
print(len(icd_code))
# Out:
# 2926

# %%
ids=list(icd_code['subject_id'])
for i in ids:
    patient.loc[(patient.subject_id==i),'icd_code']='1'

# %%
patient.icd_code.value_counts()
# Out:
# 4019       5416
# 1          2922
# 2724       2693
# I10        2483
# 30500      2120
#            ...
# C7A020        1
# O411220       1
# V0300XA       1
# 95200         1
# 7513          1
# Name: icd_code, Length: 11026, dtype: int64

# %%
chartevent=pd.read_sql_query('select subject_id,charttime,itemid,value,valueuom from mimiciv.chartevents where itemid=226730 or itemid=226512 or itemid=220621 order by subject_id,itemid,charttime',conn)
chartevent['value']=pd.to_numeric(chartevent['value'],errors='coerce')
chartevent.drop_duplicates(['subject_id','itemid'],keep='first',inplace=True)
chartevent.reset_index(drop=True,inplace=True)
chartfeatures=chartevent.pivot(index='subject_id',columns='itemid',values='value')
chartfeatures.reset_index(inplace=True)
chartfeatures_fillna=chartfeatures.fillna(chartfeatures.mean())
print(chartfeatures_fillna.shape)
# Out:
# (53129, 4)

# %%
chartfeatures_fillna.columns=['subject_id','glucose','weight','height']
df_new=patient.merge(chartfeatures_fillna)
df_new.rename(columns={'anchor_age':'age'},inplace=True)
df_new.loc[df_new['icd_code']!='1','icd_code']=0
df_new.icd_code.value_counts()
# Out:
# 0    52810
# 1      303
# Name: icd_code, dtype: int64

# %%
df_new.drop('subject_id',axis=1,inplace=True)
df_new.drop(df_new[df_new.glucose>1000].index,axis=0,inplace=True)
df_new.drop(df_new[df_new.weight>200].index,axis=0,inplace=True)
df_new.drop(df_new[df_new.height>200].index,axis=0,inplace=True)

df_new.reset_index(drop=True,inplace=True)
df_new.shape
# Out:
# (52931, 7)

# %%
df_new.drop(df_new[df_new.height==0].index,axis=0,inplace=True)
df_new.reset_index(drop=True,inplace=True)
df_new['BMI']=round(df_new['weight']/((df_new['height']/100)**2),2)
df_new.drop(df_new[df_new['BMI']>100].index,axis=0,inplace=True)
df_new.reset_index(drop=True,inplace=True)

df_new=df_new[['age','gender','glucose','weight','height','BMI','icd_code']]
df_new
# Out:
#        age gender     glucose  weight      height    BMI icd_code
# 0       52      F  115.000000    39.4  152.000000  17.05        0
# 1       73      F  411.396465    76.2  168.824223  26.74        0
# 2       55      F  113.000000    71.2  168.824223  24.98        0
# 3       46      F  146.000000    72.2  157.000000  29.29        0
# 4       68      F  148.000000    65.0  157.000000  26.37        0
# ...    ...    ...         ...     ...         ...    ...      ...
# 52745   41      M  136.000000   107.5  193.000000  28.86        0
# 52746   81      M  175.000000    50.5  168.824223  17.72        0
# 52747   46      F  192.000000    67.9  168.824223  23.82        0
# 52748   58      M   98.000000    77.5  178.000000  24.46        0
# 52749   57      F  113.000000    94.0  168.824223  32.98        0
#
# [52750 rows x 7 columns]

# %%
df_final=df_new.copy()
gender_map={'M':0,'F':1}
df_final['gender']=df_final['gender'].map(gender_map)
df_final.icd_code=pd.to_numeric(df_final.icd_code,errors='coerce')

# %%
fig=plt.subplots(figsize=(10,10))
ht=df_final.corr()
sns.heatmap(ht,annot=True)
plt.show()

# %%
df_final[['glucose','icd_code']]
df_final.icd_code.value_counts()

# df_abnormal = df_final.loc[(df_final.SBP >= 130) | (df_final.DBP >= 80), :]
# df_abnormal.icd_code.value_counts()
# Out:
# 0    52449
# 1      301
# Name: icd_code, dtype: int64

# %%
df_abnormal=df_final.loc[(df_final.glucose>=100),:]
df_abnormal.icd_code.value_counts()
# Out:
# 0    42071
# 1      201
# Name: icd_code, dtype: int64

# %%
df_abnormal_only=df_abnormal.loc[df_abnormal.icd_code==1,:]
df_abnormal_only.reset_index(drop=True,inplace=True)
df_abnormal_only
# Out:
#      age  gender  glucose  weight      height    BMI  icd_code
# 0     64       1    135.0    55.0  163.000000  20.70         1
# 1     41       1    120.0    71.3  157.000000  28.93         1
# 2     67       0    130.0    91.2  180.000000  28.15         1
# 3     43       0    140.0    78.5  173.000000  26.23         1
# 4     69       1    181.0    80.7  163.000000  30.37         1
# ..   ...     ...      ...     ...         ...    ...       ...
# 196   86       1    122.0    62.0  159.000000  24.52         1
# 197   32       1    147.0    82.0  175.000000  26.78         1
# 198   30       0    154.0    64.0  175.000000  20.90         1
# 199   35       1    197.0    55.0  163.000000  20.70         1
# 200   72       0    293.0    74.0  168.824223  25.96         1
#
# [201 rows x 7 columns]

# %%
df_normal=df_final.loc[(df_final.glucose<100),:]
df_normal.icd_code.value_counts()

# df_normal=df_final.loc[((df_final.SBP < 130) | (df_final.DBP < 80)),:]
# df_normal.icd_code.value_counts()
# Out:
# 0    10378
# 1      100
# Name: icd_code, dtype: int64

# %%
df_normal_only=df_normal.loc[df_normal.icd_code==0,:]
df_normal_only.reset_index(drop=True,inplace=True)
df_normal_only
# Out:
#        age  gender  glucose  weight      height    BMI  icd_code
# 0       53       1     98.0    96.0  157.000000  38.95         0
# 1       80       1     95.0    53.0  168.824223  18.60         0
# 2       21       0     88.0    82.0  178.000000  25.88         0
# 3       80       1     99.0    43.0  150.000000  19.11         0
# 4       24       0     90.0    67.0  168.824223  23.51         0
# ...    ...     ...      ...     ...         ...    ...       ...
# 10373   52       1     70.0    85.0  160.000000  33.20         0
# 10374   47       0     87.0    70.0  157.000000  28.40         0
# 10375   52       1     93.0    49.4  157.000000  20.04         0
# 10376   42       0     67.0    68.8  165.000000  25.27         0
# 10377   58       0     98.0    77.5  178.000000  24.46         0
#
# [10378 rows x 7 columns]

# %%
from sklearn.utils import shuffle
df=pd.concat([df_abnormal_only,df_normal_only])
df_shuffled=shuffle(df)
df_shuffled=df_shuffled.reset_index(drop=True)
df_shuffled
# Out:
#        age  gender  glucose  weight      height    BMI  icd_code
# 0       83       0     98.0    60.5  168.824223  21.23         0
# 1       51       1     98.0    78.7  170.000000  27.23         0
# 2       62       0     95.0   102.7  180.000000  31.70         0
# 3       73       0     90.0    86.0  178.000000  27.14         0
# 4       76       1    208.0    74.9  157.000000  30.39         1
# ...    ...     ...      ...     ...         ...    ...       ...
# 10574   65       0     86.0    89.0  168.000000  31.53         0
# 10575   67       0     83.0    54.0  168.824223  18.95         0
# 10576   40       1     75.0    94.0  168.000000  33.30         0
# 10577   74       0     78.0    50.2  178.000000  15.84         0
# 10578   62       0     83.0    67.4  168.824223  23.65         0
#
# [10579 rows x 7 columns]

# %%
fig=plt.subplots(figsize=(10,10))
ht=df_shuffled.corr()
sns.heatmap(ht,annot=True)
plt.show()

# %%
df_shuffled.to_csv('df_final_version.csv',index=False)
df_shuffled=pd.read_csv('df_final_version.csv')

# %%
# Y=df_shuffled[['icd_code']].values
# X=df_shuffled[['age','gender','weight','glucose','height','BMI']].values

# scaler=MinMaxScaler()
# scaler.fit(X)
# X_scaled=scaler.transform(X)
# Y_onehot=np_utils.to_categorical(Y)
# X_train,X_test,y_train,y_test=train_test_split(X_scaled,Y_onehot,test_size=0.2,random_state=0)

# %%
# def dnn_model():
#     model=Sequential()
#     model.add(Dense(32,input_shape=(6,),activation='relu'))
#     model.add(Dense(32,activation='relu'))
#     model.add(BatchNormalization())
#     model.add(Dense(64,activation='relu'))
#     model.add(Dense(64,activation='relu'))
#     model.add(BatchNormalization())
#     model.add(Dropout(0.4))
#     model.add(Dense(16,activation='relu'))
#     model.add(Dense(16,activation='relu'))
#     model.add(BatchNormalization())
#     model.add(Dropout(0.4))
#     model.add(Dense(8,activation='relu'))
#     model.add(Dense(8,activation='relu'))
#     model.add(BatchNormalization())
#     model.add(Flatten())
#     model.add(Dropout(0.4))
#     model.add(Dense(2,activation='softmax'))
#     return model
# dnn=dnn_model()
# early_stopping = EarlyStopping(monitor='val_loss', patience=50, verbose=2)
# dnn.compile(loss='categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])
# history=dnn.fit(X_train,y_train,batch_size=64,epochs=200,shuffle=False,verbose=1,validation_data=(X_test,y_test),callbacks=[early_stopping])

# %%
# score=dnn.evaluate(X_test,y_test)
# print('Test loss:',score[0])
# print('Test accuracy:',score[1])
# #plt.plot(history.epoch,history.history.get('val_accuracy'),c='g',label='validation acc')
# #plt.plot(history.epoch,history.history.get('accuracy'),c='b',label='train acc')
# plt.legend()

# %%
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score,f1_score,precision_score
# pred=np.argmax(dnn.predict(X_test),axis=1)
# y_t=np.argmax(y_test,axis=1)
# print('precision score:',precision_score(y_t,pred))
# print('f1 score:',f1_score(y_t,pred))
# print('recall score:',recall_score(y_t,pred))
# print('accuracy score:',accuracy_score(y_t,pred))

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import joblib

Y=df_shuffled[['icd_code']].values
X=df_shuffled[['glucose','age','gender','weight','BMI','height']].values

scaler=MinMaxScaler()
scaler.fit(X)
X_scaled=scaler.transform(X)
X_scaled=np.expand_dims(X_scaled,axis=2) 
joblib.dump(scaler, '/Data4TB/zhan/mimiciv_hypertension/scaler.pkl') 

Y_onehot=np_utils.to_categorical(Y)
X_train,X_test,y_train,y_test=train_test_split(X_scaled,Y_onehot,test_size=0.15,random_state=0)
def cnn_model():
    model=Sequential()
    model.add(Conv1D(32,3,input_shape=(6,1),activation='tanh',padding='same'))
    model.add(MaxPooling1D(3,padding='same'))
    model.add(SpatialDropout1D(0.3))
    model.add(Conv1D(64,3,activation='tanh',padding='same'))
    model.add(MaxPooling1D(3,padding='same'))
    model.add(SpatialDropout1D(0.3))
    model.add(Flatten())
    model.add(Dense(2,activation='softmax'))
    # print(model.summary())
    model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
    return model
cnn=cnn_model()
early_stopping = EarlyStopping(monitor='val_loss', patience=50, verbose=2)
# estimator=KerasClassifier(build_fn=cnn_model,epochs=200,batch_size=16,verbose=1,validation_data=(X_test,y_test))
history=cnn.fit(X_train,y_train,epochs=200,batch_size=32,shuffle=False,verbose=1,validation_data=(X_test,y_test),callbacks=[early_stopping])
score=cnn.evaluate(X_test,y_test)
print('Test loss:',score[0])
print('Test accuracy:',score[1])
plt.plot(history.epoch,history.history.get('val_accuracy'),c='g',label='validation acc')
plt.plot(history.epoch,history.history.get('accuracy'),c='b',label='train acc')
plt.legend()
# Out:
# 2023-11-22 13:57:15.997723: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-11-22 13:57:16.025936: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2023-11-22 13:57:16.026004: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-11-22 13:57:16.027260: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/200
# 281/281 [==============================] - 3s 8ms/step - loss: 0.1138 - accuracy: 0.9815 - val_loss: 0.1067 - val_accuracy: 0.9767
# Epoch 2/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0902 - accuracy: 0.9818 - val_loss: 0.0994 - val_accuracy: 0.9767
# Epoch 3/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0820 - accuracy: 0.9818 - val_loss: 0.0911 - val_accuracy: 0.9767
# Epoch 4/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0739 - accuracy: 0.9822 - val_loss: 0.0822 - val_accuracy: 0.9773
# Epoch 5/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0642 - accuracy: 0.9839 - val_loss: 0.0705 - val_accuracy: 0.9779
# Epoch 6/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0567 - accuracy: 0.9845 - val_loss: 0.0589 - val_accuracy: 0.9824
# Epoch 7/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0482 - accuracy: 0.9865 - val_loss: 0.0510 - val_accuracy: 0.9842
# Epoch 8/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0429 - accuracy: 0.9888 - val_loss: 0.0434 - val_accuracy: 0.9849
# Epoch 9/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0358 - accuracy: 0.9899 - val_loss: 0.0374 - val_accuracy: 0.9868
# Epoch 10/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0342 - accuracy: 0.9903 - val_loss: 0.0313 - val_accuracy: 0.9893
# Epoch 11/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0294 - accuracy: 0.9918 - val_loss: 0.0277 - val_accuracy: 0.9899
# Epoch 12/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0281 - accuracy: 0.9933 - val_loss: 0.0226 - val_accuracy: 0.9931
# Epoch 13/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0244 - accuracy: 0.9934 - val_loss: 0.0242 - val_accuracy: 0.9918
# Epoch 14/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0236 - accuracy: 0.9939 - val_loss: 0.0197 - val_accuracy: 0.9943
# Epoch 15/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0227 - accuracy: 0.9943 - val_loss: 0.0217 - val_accuracy: 0.9937
# Epoch 16/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0192 - accuracy: 0.9948 - val_loss: 0.0177 - val_accuracy: 0.9943
# Epoch 17/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0207 - accuracy: 0.9954 - val_loss: 0.0157 - val_accuracy: 0.9950
# Epoch 18/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0176 - accuracy: 0.9956 - val_loss: 0.0159 - val_accuracy: 0.9956
# Epoch 19/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0179 - accuracy: 0.9954 - val_loss: 0.0150 - val_accuracy: 0.9956
# Epoch 20/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0180 - accuracy: 0.9956 - val_loss: 0.0135 - val_accuracy: 0.9968
# Epoch 21/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0166 - accuracy: 0.9959 - val_loss: 0.0142 - val_accuracy: 0.9956
# Epoch 22/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0162 - accuracy: 0.9959 - val_loss: 0.0151 - val_accuracy: 0.9950
# Epoch 23/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0145 - accuracy: 0.9964 - val_loss: 0.0158 - val_accuracy: 0.9956
# Epoch 24/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0161 - accuracy: 0.9959 - val_loss: 0.0130 - val_accuracy: 0.9968
# Epoch 25/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0140 - accuracy: 0.9962 - val_loss: 0.0146 - val_accuracy: 0.9956
# Epoch 26/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0127 - accuracy: 0.9966 - val_loss: 0.0139 - val_accuracy: 0.9956
# Epoch 27/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0130 - accuracy: 0.9968 - val_loss: 0.0119 - val_accuracy: 0.9968
# Epoch 28/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0119 - accuracy: 0.9972 - val_loss: 0.0129 - val_accuracy: 0.9962
# Epoch 29/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0121 - accuracy: 0.9972 - val_loss: 0.0109 - val_accuracy: 0.9968
# Epoch 30/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0128 - accuracy: 0.9966 - val_loss: 0.0132 - val_accuracy: 0.9962
# Epoch 31/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0111 - accuracy: 0.9971 - val_loss: 0.0107 - val_accuracy: 0.9968
# Epoch 32/200
# 281/281 [==============================] - 3s 9ms/step - loss: 0.0119 - accuracy: 0.9970 - val_loss: 0.0140 - val_accuracy: 0.9962
# Epoch 33/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0104 - accuracy: 0.9972 - val_loss: 0.0128 - val_accuracy: 0.9968
# Epoch 34/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0096 - accuracy: 0.9977 - val_loss: 0.0169 - val_accuracy: 0.9956
# Epoch 35/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0093 - accuracy: 0.9976 - val_loss: 0.0111 - val_accuracy: 0.9975
# Epoch 36/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0116 - accuracy: 0.9968 - val_loss: 0.0132 - val_accuracy: 0.9968
# Epoch 37/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0093 - accuracy: 0.9982 - val_loss: 0.0104 - val_accuracy: 0.9968
# Epoch 38/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0079 - accuracy: 0.9979 - val_loss: 0.0104 - val_accuracy: 0.9968
# Epoch 39/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0090 - accuracy: 0.9977 - val_loss: 0.0103 - val_accuracy: 0.9975
# Epoch 40/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0095 - accuracy: 0.9976 - val_loss: 0.0186 - val_accuracy: 0.9956
# Epoch 41/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0085 - accuracy: 0.9977 - val_loss: 0.0136 - val_accuracy: 0.9962
# Epoch 42/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0081 - accuracy: 0.9977 - val_loss: 0.0108 - val_accuracy: 0.9975
# Epoch 43/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0094 - accuracy: 0.9976 - val_loss: 0.0114 - val_accuracy: 0.9968
# Epoch 44/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0096 - accuracy: 0.9973 - val_loss: 0.0130 - val_accuracy: 0.9962
# Epoch 45/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0082 - accuracy: 0.9976 - val_loss: 0.0092 - val_accuracy: 0.9981
# Epoch 46/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0093 - accuracy: 0.9972 - val_loss: 0.0109 - val_accuracy: 0.9968
# Epoch 47/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0085 - accuracy: 0.9974 - val_loss: 0.0122 - val_accuracy: 0.9962
# Epoch 48/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0084 - accuracy: 0.9972 - val_loss: 0.0126 - val_accuracy: 0.9962
# Epoch 49/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0080 - accuracy: 0.9980 - val_loss: 0.0094 - val_accuracy: 0.9981
# Epoch 50/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0077 - accuracy: 0.9979 - val_loss: 0.0098 - val_accuracy: 0.9981
# Epoch 51/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0083 - accuracy: 0.9982 - val_loss: 0.0092 - val_accuracy: 0.9981
# Epoch 52/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0073 - accuracy: 0.9983 - val_loss: 0.0175 - val_accuracy: 0.9962
# Epoch 53/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0087 - accuracy: 0.9981 - val_loss: 0.0114 - val_accuracy: 0.9968
# Epoch 54/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0075 - accuracy: 0.9981 - val_loss: 0.0118 - val_accuracy: 0.9968
# Epoch 55/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0068 - accuracy: 0.9982 - val_loss: 0.0082 - val_accuracy: 0.9981
# Epoch 56/200
# 281/281 [==============================] - 3s 9ms/step - loss: 0.0083 - accuracy: 0.9980 - val_loss: 0.0143 - val_accuracy: 0.9962
# Epoch 57/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.0114 - val_accuracy: 0.9968
# Epoch 58/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0062 - accuracy: 0.9983 - val_loss: 0.0092 - val_accuracy: 0.9981
# Epoch 59/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0072 - accuracy: 0.9981 - val_loss: 0.0081 - val_accuracy: 0.9981
# Epoch 60/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.0147 - val_accuracy: 0.9962
# Epoch 61/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0074 - accuracy: 0.9982 - val_loss: 0.0107 - val_accuracy: 0.9962
# Epoch 62/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0082 - accuracy: 0.9980 - val_loss: 0.0144 - val_accuracy: 0.9962
# Epoch 63/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0074 - accuracy: 0.9984 - val_loss: 0.0114 - val_accuracy: 0.9968
# Epoch 64/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0074 - accuracy: 0.9984 - val_loss: 0.0095 - val_accuracy: 0.9981
# Epoch 65/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0070 - accuracy: 0.9980 - val_loss: 0.0139 - val_accuracy: 0.9962
# Epoch 66/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0060 - accuracy: 0.9984 - val_loss: 0.0064 - val_accuracy: 0.9981
# Epoch 67/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0085 - accuracy: 0.9977 - val_loss: 0.0271 - val_accuracy: 0.9956
# Epoch 68/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0074 - accuracy: 0.9979 - val_loss: 0.0087 - val_accuracy: 0.9981
# Epoch 69/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0069 - accuracy: 0.9984 - val_loss: 0.0058 - val_accuracy: 0.9981
# Epoch 70/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0069 - accuracy: 0.9986 - val_loss: 0.0069 - val_accuracy: 0.9981
# Epoch 71/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0064 - accuracy: 0.9984 - val_loss: 0.0207 - val_accuracy: 0.9962
# Epoch 72/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0088 - accuracy: 0.9974 - val_loss: 0.0116 - val_accuracy: 0.9968
# Epoch 73/200
# 281/281 [==============================] - 3s 9ms/step - loss: 0.0079 - accuracy: 0.9981 - val_loss: 0.0111 - val_accuracy: 0.9962
# Epoch 74/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0074 - accuracy: 0.9981 - val_loss: 0.0070 - val_accuracy: 0.9981
# Epoch 75/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.0086 - val_accuracy: 0.9981
# Epoch 76/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0060 - accuracy: 0.9981 - val_loss: 0.0121 - val_accuracy: 0.9968
# Epoch 77/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0090 - accuracy: 0.9979 - val_loss: 0.0215 - val_accuracy: 0.9962
# Epoch 78/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0070 - accuracy: 0.9981 - val_loss: 0.0075 - val_accuracy: 0.9981
# Epoch 79/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0050 - accuracy: 0.9988 - val_loss: 0.0084 - val_accuracy: 0.9981
# Epoch 80/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0074 - accuracy: 0.9983 - val_loss: 0.0161 - val_accuracy: 0.9962
# Epoch 81/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0062 - accuracy: 0.9984 - val_loss: 0.0173 - val_accuracy: 0.9962
# Epoch 82/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0075 - accuracy: 0.9979 - val_loss: 0.0377 - val_accuracy: 0.9950
# Epoch 83/200
# 281/281 [==============================] - 2s 6ms/step - loss: 0.0074 - accuracy: 0.9978 - val_loss: 0.0179 - val_accuracy: 0.9962
# Epoch 84/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0072 - accuracy: 0.9986 - val_loss: 0.0093 - val_accuracy: 0.9981
# Epoch 85/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0066 - accuracy: 0.9987 - val_loss: 0.0097 - val_accuracy: 0.9981
# Epoch 86/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0062 - accuracy: 0.9983 - val_loss: 0.0104 - val_accuracy: 0.9981
# Epoch 87/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0062 - accuracy: 0.9983 - val_loss: 0.0093 - val_accuracy: 0.9981
# Epoch 88/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0055 - accuracy: 0.9987 - val_loss: 0.0097 - val_accuracy: 0.9981
# Epoch 89/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.0093 - val_accuracy: 0.9981
# Epoch 90/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0060 - accuracy: 0.9984 - val_loss: 0.0099 - val_accuracy: 0.9981
# Epoch 91/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0071 - accuracy: 0.9982 - val_loss: 0.0107 - val_accuracy: 0.9981
# Epoch 92/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0061 - accuracy: 0.9987 - val_loss: 0.0264 - val_accuracy: 0.9956
# Epoch 93/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0090 - accuracy: 0.9973 - val_loss: 0.0077 - val_accuracy: 0.9981
# Epoch 94/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.0102 - val_accuracy: 0.9981
# Epoch 95/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.0103 - val_accuracy: 0.9981
# Epoch 96/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0061 - accuracy: 0.9983 - val_loss: 0.0063 - val_accuracy: 0.9981
# Epoch 97/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0058 - accuracy: 0.9987 - val_loss: 0.0109 - val_accuracy: 0.9975
# Epoch 98/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0067 - accuracy: 0.9981 - val_loss: 0.0052 - val_accuracy: 0.9987
# Epoch 99/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.0124 - val_accuracy: 0.9975
# Epoch 100/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0062 - accuracy: 0.9983 - val_loss: 0.0072 - val_accuracy: 0.9981
# Epoch 101/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0067 - accuracy: 0.9981 - val_loss: 0.0063 - val_accuracy: 0.9981
# Epoch 102/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0078 - accuracy: 0.9981 - val_loss: 0.0068 - val_accuracy: 0.9981
# Epoch 103/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.0160 - val_accuracy: 0.9962
# Epoch 104/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 0.0072 - val_accuracy: 0.9981
# Epoch 105/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0087 - accuracy: 0.9981 - val_loss: 0.0091 - val_accuracy: 0.9981
# Epoch 106/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0063 - accuracy: 0.9983 - val_loss: 0.0101 - val_accuracy: 0.9981
# Epoch 107/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0077 - accuracy: 0.9976 - val_loss: 0.0356 - val_accuracy: 0.9956
# Epoch 108/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0062 - accuracy: 0.9986 - val_loss: 0.0086 - val_accuracy: 0.9981
# Epoch 109/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.0079 - val_accuracy: 0.9981
# Epoch 110/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0072 - accuracy: 0.9987 - val_loss: 0.0231 - val_accuracy: 0.9962
# Epoch 111/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0052 - accuracy: 0.9982 - val_loss: 0.0168 - val_accuracy: 0.9962
# Epoch 112/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.0088 - val_accuracy: 0.9981
# Epoch 113/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0052 - accuracy: 0.9989 - val_loss: 0.0056 - val_accuracy: 0.9987
# Epoch 114/200
# 281/281 [==============================] - 3s 9ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.0093 - val_accuracy: 0.9981
# Epoch 115/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0063 - accuracy: 0.9987 - val_loss: 0.0051 - val_accuracy: 0.9981
# Epoch 116/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0067 - accuracy: 0.9981 - val_loss: 0.0240 - val_accuracy: 0.9962
# Epoch 117/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0072 - accuracy: 0.9982 - val_loss: 0.0102 - val_accuracy: 0.9981
# Epoch 118/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.0096 - val_accuracy: 0.9981
# Epoch 119/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.0088 - val_accuracy: 0.9981
# Epoch 120/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0052 - accuracy: 0.9987 - val_loss: 0.0110 - val_accuracy: 0.9981
# Epoch 121/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0072 - accuracy: 0.9984 - val_loss: 0.0100 - val_accuracy: 0.9981
# Epoch 122/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.0064 - val_accuracy: 0.9981
# Epoch 123/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0078 - accuracy: 0.9978 - val_loss: 0.0100 - val_accuracy: 0.9981
# Epoch 124/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0058 - accuracy: 0.9982 - val_loss: 0.0070 - val_accuracy: 0.9981
# Epoch 125/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.0068 - val_accuracy: 0.9981
# Epoch 126/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0074 - accuracy: 0.9982 - val_loss: 0.0071 - val_accuracy: 0.9981
# Epoch 127/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0058 - accuracy: 0.9987 - val_loss: 0.0071 - val_accuracy: 0.9981
# Epoch 128/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0050 - accuracy: 0.9988 - val_loss: 0.0068 - val_accuracy: 0.9981
# Epoch 129/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.0241 - val_accuracy: 0.9962
# Epoch 130/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0075 - accuracy: 0.9984 - val_loss: 0.0092 - val_accuracy: 0.9981
# Epoch 131/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0066 - accuracy: 0.9984 - val_loss: 0.0089 - val_accuracy: 0.9981
# Epoch 132/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0063 - accuracy: 0.9984 - val_loss: 0.0074 - val_accuracy: 0.9981
# Epoch 133/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.0086 - val_accuracy: 0.9981
# Epoch 134/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0058 - accuracy: 0.9979 - val_loss: 0.0069 - val_accuracy: 0.9981
# Epoch 135/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.0081 - val_accuracy: 0.9981
# Epoch 136/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0058 - accuracy: 0.9986 - val_loss: 0.0084 - val_accuracy: 0.9981
# Epoch 137/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0058 - accuracy: 0.9988 - val_loss: 0.0070 - val_accuracy: 0.9981
# Epoch 138/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 0.0089 - val_accuracy: 0.9981
# Epoch 139/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 0.0242 - val_accuracy: 0.9962
# Epoch 140/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0054 - accuracy: 0.9984 - val_loss: 0.0096 - val_accuracy: 0.9981
# Epoch 141/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0055 - accuracy: 0.9987 - val_loss: 0.0134 - val_accuracy: 0.9968
# Epoch 142/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0047 - accuracy: 0.9982 - val_loss: 0.0065 - val_accuracy: 0.9987
# Epoch 143/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0070 - accuracy: 0.9979 - val_loss: 0.0092 - val_accuracy: 0.9981
# Epoch 144/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0146 - val_accuracy: 0.9968
# Epoch 145/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0066 - accuracy: 0.9982 - val_loss: 0.0063 - val_accuracy: 0.9987
# Epoch 146/200
# 281/281 [==============================] - 3s 9ms/step - loss: 0.0066 - accuracy: 0.9982 - val_loss: 0.0341 - val_accuracy: 0.9956
# Epoch 147/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0066 - accuracy: 0.9983 - val_loss: 0.0246 - val_accuracy: 0.9962
# Epoch 148/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 0.0080 - val_accuracy: 0.9981
# Epoch 149/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.0156 - val_accuracy: 0.9962
# Epoch 150/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 0.0268 - val_accuracy: 0.9962
# Epoch 151/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0059 - accuracy: 0.9986 - val_loss: 0.0110 - val_accuracy: 0.9975
# Epoch 152/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0042 - accuracy: 0.9989 - val_loss: 0.0130 - val_accuracy: 0.9962
# Epoch 153/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0056 - accuracy: 0.9987 - val_loss: 0.0045 - val_accuracy: 0.9987
# Epoch 154/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.0068 - val_accuracy: 0.9981
# Epoch 155/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0057 - accuracy: 0.9980 - val_loss: 0.0083 - val_accuracy: 0.9981
# Epoch 156/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0048 - accuracy: 0.9988 - val_loss: 0.0175 - val_accuracy: 0.9962
# Epoch 157/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0060 - accuracy: 0.9986 - val_loss: 0.0063 - val_accuracy: 0.9981
# Epoch 158/200
# 281/281 [==============================] - 3s 9ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.0212 - val_accuracy: 0.9962
# Epoch 159/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 0.0140 - val_accuracy: 0.9968
# Epoch 160/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.0067 - val_accuracy: 0.9981
# Epoch 161/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0058 - accuracy: 0.9983 - val_loss: 0.0069 - val_accuracy: 0.9981
# Epoch 162/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0055 - accuracy: 0.9984 - val_loss: 0.0098 - val_accuracy: 0.9981
# Epoch 163/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.0055 - val_accuracy: 0.9987
# Epoch 164/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.0067 - val_accuracy: 0.9981
# Epoch 165/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0072 - accuracy: 0.9979 - val_loss: 0.0098 - val_accuracy: 0.9981
# Epoch 166/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.0101 - val_accuracy: 0.9981
# Epoch 167/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0052 - accuracy: 0.9986 - val_loss: 0.0291 - val_accuracy: 0.9962
# Epoch 168/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.0092 - val_accuracy: 0.9981
# Epoch 169/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0057 - accuracy: 0.9988 - val_loss: 0.0071 - val_accuracy: 0.9981
# Epoch 170/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0048 - accuracy: 0.9988 - val_loss: 0.0087 - val_accuracy: 0.9981
# Epoch 171/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.0086 - val_accuracy: 0.9981
# Epoch 172/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0032 - accuracy: 0.9989 - val_loss: 0.0078 - val_accuracy: 0.9981
# Epoch 173/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0075 - accuracy: 0.9984 - val_loss: 0.0068 - val_accuracy: 0.9981
# Epoch 174/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.0166 - val_accuracy: 0.9968
# Epoch 175/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.0051 - val_accuracy: 0.9987
# Epoch 176/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0042 - accuracy: 0.9988 - val_loss: 0.0189 - val_accuracy: 0.9962
# Epoch 177/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0042 - accuracy: 0.9991 - val_loss: 0.0087 - val_accuracy: 0.9981
# Epoch 178/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0061 - accuracy: 0.9988 - val_loss: 0.0117 - val_accuracy: 0.9981
# Epoch 179/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0044 - accuracy: 0.9989 - val_loss: 0.0094 - val_accuracy: 0.9981
# Epoch 180/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0051 - accuracy: 0.9990 - val_loss: 0.0071 - val_accuracy: 0.9981
# Epoch 181/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.0097 - val_accuracy: 0.9981
# Epoch 182/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.0062 - val_accuracy: 0.9981
# Epoch 183/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.0121 - val_accuracy: 0.9962
# Epoch 184/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0068 - accuracy: 0.9986 - val_loss: 0.0274 - val_accuracy: 0.9962
# Epoch 185/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0058 - accuracy: 0.9982 - val_loss: 0.0160 - val_accuracy: 0.9962
# Epoch 186/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.0058 - val_accuracy: 0.9981
# Epoch 187/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.0077 - val_accuracy: 0.9981
# Epoch 188/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0055 - accuracy: 0.9982 - val_loss: 0.0058 - val_accuracy: 0.9987
# Epoch 189/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0036 - accuracy: 0.9987 - val_loss: 0.0120 - val_accuracy: 0.9981
# Epoch 190/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0076 - val_accuracy: 0.9981
# Epoch 191/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0049 - accuracy: 0.9988 - val_loss: 0.0065 - val_accuracy: 0.9987
# Epoch 192/200
# 281/281 [==============================] - 3s 9ms/step - loss: 0.0097 - accuracy: 0.9976 - val_loss: 0.0089 - val_accuracy: 0.9981
# Epoch 193/200
# 281/281 [==============================] - 2s 7ms/step - loss: 0.0030 - accuracy: 0.9993 - val_loss: 0.0053 - val_accuracy: 0.9981
# Epoch 194/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0083 - val_accuracy: 0.9981
# Epoch 195/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0033 - accuracy: 0.9994 - val_loss: 0.0070 - val_accuracy: 0.9981
# Epoch 196/200
# 281/281 [==============================] - 2s 9ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.0093 - val_accuracy: 0.9981
# Epoch 197/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.0166 - val_accuracy: 0.9962
# Epoch 198/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0043 - accuracy: 0.9989 - val_loss: 0.0149 - val_accuracy: 0.9962
# Epoch 199/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0047 - accuracy: 0.9990 - val_loss: 0.0079 - val_accuracy: 0.9981
# Epoch 200/200
# 281/281 [==============================] - 2s 8ms/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 0.0276 - val_accuracy: 0.9962
# 50/50 [==============================] - 0s 7ms/step - loss: 0.0276 - accuracy: 0.9962
# Test loss: 0.027599142864346504
# Test accuracy: 0.996219277381897

# %%
pred=np.argmax(cnn.predict(X_test),axis=1)
y_t=np.argmax(y_test,axis=1)
print('precision score:',precision_score(y_t,pred))
print('f1 score:',f1_score(y_t,pred))
print('recall score:',recall_score(y_t,pred))
print('accuracy score:',accuracy_score(y_t,pred))
# Out:
# 50/50 [==============================] - 0s 4ms/step
# precision score: 1.0
# f1 score: 0.911764705882353
# recall score: 0.8378378378378378
# accuracy score: 0.996219281663516

# %%
cnn.save("hypertension.h5")
